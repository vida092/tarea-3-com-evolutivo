# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import time

# %%
xmin = -5.12
xmax = 5.12
dim = 10
pres = 3
longitud = int(math.log2( (xmax-xmin)*(10**pres) )+0.9)
prob_mut = 0.03
prob_cruza = 0.8
pobsize = 250
num_generaciones = 1000
num_padres = 16

dim_disc = dim * longitud

# %%
def bin2dec(bin_str):
    return int(''.join(str(x) for x in bin_str), 2)

# %%
def vbin2vdec(vbin, bits_per_var=longitud, num_vars=dim, vmin=xmin, vmax=xmax):
    vdec = []
    max_dec = 2**bits_per_var - 1
    for i in range(num_vars):
        bin_segment = vbin[i*bits_per_var:(i+1)*bits_per_var]
        dec = bin2dec(bin_segment)
        scaled_val = vmin + ((vmax - vmin) / max_dec) * dec
        vdec.append(scaled_val)
    return vdec

# %%
def aptitud(vbin):
    vdec = np.array(vbin2vdec(vbin))
    suma = np.sum(vdec**2 - 10 * np.cos(2 * np.pi * vdec))
    resultado = 10*dim + suma
    return resultado


def evaluar_aptitud(individuos):
    return [aptitud(ind) for ind in individuos]

# %%
def generate_pob(pobsize):
    pob = []
    for i in range(pobsize):        
        vector = np.random.randint(0, 2, size=dim_disc)
        pob.append(vector)
    return pob

# %%
def crossover_uniforme(v1, v2, prob_cruza):
    if np.random.rand() < prob_cruza:
        mascara = np.random.randint(0, 2, size=len(v1)).astype(bool)
        inversa_mascara = np.logical_not(mascara)
        h1 = np.where(mascara, v1, v2)
        h2 = np.where(mascara, v2, v1)
    else:
        h1 = v1
        h2 = v2
    return h1, h2

# %%
def mutacion_uniforme_binaria(vector, prob_mut):
    mascara = np.random.random(size=len(vector)) < prob_mut
    vector[mascara] = 1 - vector[mascara]    
    return vector

# %% [markdown]
# * Calcula la aptitud total de la población para determinar el tamaño de los "segmentos" de la ruleta para cada individuo.
# * Establece un punto de inicio aleatorio y un intervalo constante (punto de ruleta) para realizar la selección.
# * Recorre la población, acumulando la aptitud y seleccionando individuos cuando la aptitud acumulada supera los puntos establecidos por el intervalo.

# %%
def seleccion_universal_estocastica(poblacion, aptitudes, num_padres):
    max_aptitud = max(aptitudes)
    aptitudes_invertidas = [max_aptitud - a for a in aptitudes]
    aptitudes_sum = sum(aptitudes_invertidas)
    puntos_seleccion = np.linspace(0, aptitudes_sum, num_padres, endpoint=False)
    punto_inicio = np.random.uniform(0, aptitudes_sum / num_padres)
    puntos_seleccion += punto_inicio

    padres = []
    indice_actual = 0
    suma_acumulada = aptitudes_invertidas[indice_actual]
    for punto in puntos_seleccion:
        while suma_acumulada < punto:
            indice_actual += 1
            suma_acumulada += aptitudes_invertidas[indice_actual]
        padres.append(poblacion[indice_actual])
    return padres

# %%
# start_time = time.time()

# poblacion = generate_pob(pobsize)
# for gen in range(num_generaciones):
#     aptitudes = evaluar_aptitud(poblacion)
#     padres = seleccion_universal_estocastica(poblacion, aptitudes, num_padres)
    
#     nueva_poblacion = []
#     for i in range(0, num_padres, 2):
#         padre1 = padres[i]
#         padre2 = padres[i + 1]
#         hijo1, hijo2 = crossover_uniforme(padre1, padre2, prob_cruza)
#         hijo1 = mutacion_uniforme_binaria(hijo1, prob_mut)
#         hijo2 = mutacion_uniforme_binaria(hijo2, prob_mut)
#         nueva_poblacion.extend([hijo1, hijo2])
    
#     poblacion.extend(nueva_poblacion)
#     aptitudes = evaluar_aptitud(poblacion)
#     indices_mejores = np.argsort(aptitudes)[:pobsize]
#     poblacion = [poblacion[i] for i in indices_mejores]
#     print(f"generación {gen}, Mejor {aptitud(poblacion[0])}")
    
# end_time = time.time()
# elapsed_time = end_time - start_time

# print(f"El tiempo de ejecución es: {elapsed_time} segundos")

# # Resultados finales
# aptitudes_finales = evaluar_aptitud(poblacion)
# mejor_individuo = poblacion[np.argmin(aptitudes_finales)]
# mejor_aptitud = min(aptitudes_finales)

# print("Mejor aptitud:", mejor_aptitud)
# print("Mejor individuo:", mejor_individuo)
# print("Valores decodificados:", vbin2vdec(mejor_individuo))

# %%
start_time = time.time()

poblacion = generate_pob(pobsize)
for gen in range(num_generaciones):
    aptitudes = evaluar_aptitud(poblacion)
    indices_mejores = np.argsort(aptitudes)[:5]
    elite = [poblacion[i] for i in indices_mejores]

    padres = seleccion_universal_estocastica(poblacion, aptitudes, num_padres)

    nueva_poblacion = elite[:]  # Agregar individuos élite a la nueva población
    while len(nueva_poblacion) < pobsize:
        for i in range(0, num_padres, 2):
            padre1 = padres[i]
            padre2 = padres[i + 1]
            hijo1, hijo2 = crossover_uniforme(padre1, padre2, prob_cruza)
            hijo1 = mutacion_uniforme_binaria(hijo1, prob_mut)
            hijo2 = mutacion_uniforme_binaria(hijo2, prob_mut)
            nueva_poblacion.extend([hijo1, hijo2])
            if len(nueva_poblacion) >= pobsize:
                break

    # Evaluar aptitudes de la nueva población expandida
    poblacion.extend(nueva_poblacion)
    poblacion = sorted(poblacion, key=aptitud)[:pobsize]  # Ordenar y reducir a pobsize

    # Guardar y mostrar el mejor individuo
    mejor_aptitud = aptitud(poblacion[0])

    # Guardar y mostrar el mejor individuo
    mejor_aptitud = min(evaluar_aptitud(poblacion))
    print(f"Generación {gen}, Mejor aptitud: {mejor_aptitud}")

end_time = time.time()
elapsed_time = end_time - start_time

print(f"El tiempo de ejecución es: {elapsed_time} segundos")

# Resultados finales
aptitudes_finales = evaluar_aptitud(poblacion)
mejor_individuo = poblacion[np.argmin(aptitudes_finales)]
mejor_aptitud = min(aptitudes_finales)

print("Mejor aptitud:", mejor_aptitud)
print("Mejor individuo:", mejor_individuo)
print("Valores decodificados:", vbin2vdec(mejor_individuo))
# Out:
# Generación 0, Mejor aptitud: 97.68715296502427
# Generación 1, Mejor aptitud: 97.3577730198982
# Generación 2, Mejor aptitud: 73.59634489553932
# Generación 3, Mejor aptitud: 73.59634489553932
# Generación 4, Mejor aptitud: 79.98198703740755
# Generación 5, Mejor aptitud: 57.15287438759237
# Generación 6, Mejor aptitud: 57.15287438759237
# Generación 7, Mejor aptitud: 60.953875107979286
# Generación 8, Mejor aptitud: 60.953875107979286
# Generación 9, Mejor aptitud: 64.85353379894835
# Generación 10, Mejor aptitud: 55.20082592671906
# Generación 11, Mejor aptitud: 47.693054273914406
# Generación 12, Mejor aptitud: 47.693054273914406
# Generación 13, Mejor aptitud: 54.65365052037566
# Generación 14, Mejor aptitud: 45.20657954131536
# Generación 15, Mejor aptitud: 33.01363031454993
# Generación 16, Mejor aptitud: 31.772019731457178
# Generación 17, Mejor aptitud: 31.772019731457178
# Generación 18, Mejor aptitud: 34.807772484547655
# Generación 19, Mejor aptitud: 24.200417171350892
# Generación 20, Mejor aptitud: 32.146659853848774
# Generación 21, Mejor aptitud: 35.35313997964073
# Generación 22, Mejor aptitud: 32.756539951253075
# Generación 23, Mejor aptitud: 32.3933867250137
# Generación 24, Mejor aptitud: 28.39214458491074
# Generación 25, Mejor aptitud: 28.39214458491074
# Generación 26, Mejor aptitud: 26.227157709219895
# Generación 27, Mejor aptitud: 35.39249200762012
# Generación 28, Mejor aptitud: 28.8250078720221
# Generación 29, Mejor aptitud: 28.8250078720221
# Generación 30, Mejor aptitud: 28.8250078720221
# Generación 31, Mejor aptitud: 22.794543125699562
# Generación 32, Mejor aptitud: 23.486574192113906
# Generación 33, Mejor aptitud: 23.486574192113906
# Generación 34, Mejor aptitud: 23.064957663806425
# Generación 35, Mejor aptitud: 19.7453494911921
# Generación 36, Mejor aptitud: 19.7453494911921
# Generación 37, Mejor aptitud: 22.604008815808896
# Generación 38, Mejor aptitud: 22.604008815808896
# Generación 39, Mejor aptitud: 24.68594861601929
# Generación 40, Mejor aptitud: 30.236234753108903
# Generación 41, Mejor aptitud: 30.236234753108903
# Generación 42, Mejor aptitud: 30.77449196041188
# Generación 43, Mejor aptitud: 28.86145688753345
# Generación 44, Mejor aptitud: 27.78540327185239
# Generación 45, Mejor aptitud: 25.600299012444353
# Generación 46, Mejor aptitud: 25.600299012444353
# Generación 47, Mejor aptitud: 25.600299012444353
# Generación 48, Mejor aptitud: 25.600299012444353
# Generación 49, Mejor aptitud: 22.232395590085147
# Generación 50, Mejor aptitud: 22.232395590085147
# Generación 51, Mejor aptitud: 22.232395590085147
# Generación 52, Mejor aptitud: 23.578497601289868
# Generación 53, Mejor aptitud: 21.727321654641685
# Generación 54, Mejor aptitud: 21.31411275609807
# Generación 55, Mejor aptitud: 21.31411275609807
# Generación 56, Mejor aptitud: 24.228908744675238
# Generación 57, Mejor aptitud: 24.228908744675238
# Generación 58, Mejor aptitud: 22.585449447718403
# Generación 59, Mejor aptitud: 22.474853787136254
# Generación 60, Mejor aptitud: 21.204435972116215
# Generación 61, Mejor aptitud: 21.204435972116215
# Generación 62, Mejor aptitud: 23.536856085917876
# Generación 63, Mejor aptitud: 23.536856085917876
# Generación 64, Mejor aptitud: 23.536856085917876
# Generación 65, Mejor aptitud: 21.414500252932257
# Generación 66, Mejor aptitud: 21.414500252932257
# Generación 67, Mejor aptitud: 22.86220258448543
# Generación 68, Mejor aptitud: 22.766488125057293
# Generación 69, Mejor aptitud: 20.41000659413234
# Generación 70, Mejor aptitud: 20.41000659413234
# Generación 71, Mejor aptitud: 20.41000659413234
# Generación 72, Mejor aptitud: 22.619569339226146
# Generación 73, Mejor aptitud: 22.619569339226146
# Generación 74, Mejor aptitud: 22.619569339226146
# Generación 75, Mejor aptitud: 20.72805615678638
# Generación 76, Mejor aptitud: 23.173707502038837
# Generación 77, Mejor aptitud: 23.173707502038837
# Generación 78, Mejor aptitud: 21.13638938701439
# Generación 79, Mejor aptitud: 21.13638938701439
# Generación 80, Mejor aptitud: 19.080334092349133
# Generación 81, Mejor aptitud: 19.080334092349133
# Generación 82, Mejor aptitud: 19.080334092349133
# Generación 83, Mejor aptitud: 18.792093051575435
# Generación 84, Mejor aptitud: 18.792093051575435
# Generación 85, Mejor aptitud: 19.286110544864954
# Generación 86, Mejor aptitud: 18.621304526103486
# Generación 87, Mejor aptitud: 18.621304526103486
# Generación 88, Mejor aptitud: 19.45536134783582
# Generación 89, Mejor aptitud: 19.863087179646243
# Generación 90, Mejor aptitud: 19.863087179646243
# Generación 91, Mejor aptitud: 22.210873787553908
# Generación 92, Mejor aptitud: 22.210873787553908
# Generación 93, Mejor aptitud: 21.729690999960468
# Generación 94, Mejor aptitud: 23.168610040567458
# Generación 95, Mejor aptitud: 23.512966522804675
# Generación 96, Mejor aptitud: 23.512966522804675
# Generación 97, Mejor aptitud: 21.70477749933444
# Generación 98, Mejor aptitud: 21.70477749933444
# Generación 99, Mejor aptitud: 21.8676568739008
# Generación 100, Mejor aptitud: 21.8676568739008
# Generación 101, Mejor aptitud: 23.345242346694633
# Generación 102, Mejor aptitud: 23.345242346694633
# Generación 103, Mejor aptitud: 17.014556411721216
# Generación 104, Mejor aptitud: 17.014556411721216
# Generación 105, Mejor aptitud: 17.014556411721216
# Generación 106, Mejor aptitud: 16.689455887495058
# Generación 107, Mejor aptitud: 16.689455887495058
# Generación 108, Mejor aptitud: 16.689455887495058
# Generación 109, Mejor aptitud: 15.435015514595193
# Generación 110, Mejor aptitud: 15.435015514595193
# Generación 111, Mejor aptitud: 15.435015514595193
# Generación 112, Mejor aptitud: 15.370916405016516
# Generación 113, Mejor aptitud: 15.370916405016516
# Generación 114, Mejor aptitud: 15.490900173190255
# Generación 115, Mejor aptitud: 15.082772663202704
# Generación 116, Mejor aptitud: 15.09423345058542
# Generación 117, Mejor aptitud: 15.09423345058542
# Generación 118, Mejor aptitud: 16.18838020631796
# Generación 119, Mejor aptitud: 16.18838020631796
# Generación 120, Mejor aptitud: 17.01134145649152
# Generación 121, Mejor aptitud: 17.699623928282094
# Generación 122, Mejor aptitud: 15.600461197482659
# Generación 123, Mejor aptitud: 15.600461197482659
# Generación 124, Mejor aptitud: 15.230835743742915
# Generación 125, Mejor aptitud: 18.91957469674273
# Generación 126, Mejor aptitud: 17.170160825973284
# Generación 127, Mejor aptitud: 17.170160825973284
# Generación 128, Mejor aptitud: 18.597725469451078
# Generación 129, Mejor aptitud: 17.216709253149602
# Generación 130, Mejor aptitud: 17.568059305578373
# Generación 131, Mejor aptitud: 17.568059305578373
# Generación 132, Mejor aptitud: 17.568059305578373
# Generación 133, Mejor aptitud: 17.394370394756947
# Generación 134, Mejor aptitud: 17.394370394756947
# Generación 135, Mejor aptitud: 17.394370394756947
# Generación 136, Mejor aptitud: 17.631327259824246
# Generación 137, Mejor aptitud: 18.060848250030162
# Generación 138, Mejor aptitud: 17.578344868132618
# Generación 139, Mejor aptitud: 17.857860163711763
# Generación 140, Mejor aptitud: 19.460061434225324
# Generación 141, Mejor aptitud: 18.261040849953403
# Generación 142, Mejor aptitud: 16.73318970282824
# Generación 143, Mejor aptitud: 16.73318970282824
# Generación 144, Mejor aptitud: 20.640695284945792
# Generación 145, Mejor aptitud: 20.01560656050418
# Generación 146, Mejor aptitud: 18.372737143835494
# Generación 147, Mejor aptitud: 17.34062838433769
# Generación 148, Mejor aptitud: 19.00325737370855
# Generación 149, Mejor aptitud: 18.357989150079447
# Generación 150, Mejor aptitud: 18.357989150079447
# Generación 151, Mejor aptitud: 18.357989150079447
# Generación 152, Mejor aptitud: 18.934565048341497
# Generación 153, Mejor aptitud: 18.83659453943639
# Generación 154, Mejor aptitud: 17.750570715871604
# Generación 155, Mejor aptitud: 17.750570715871604
# Generación 156, Mejor aptitud: 15.907454979476029
# Generación 157, Mejor aptitud: 15.907454979476029
# Generación 158, Mejor aptitud: 15.907454979476029
# Generación 159, Mejor aptitud: 16.632092496495346
# Generación 160, Mejor aptitud: 18.060520817772726
# Generación 161, Mejor aptitud: 17.879365733998355
# Generación 162, Mejor aptitud: 17.879365733998355
# Generación 163, Mejor aptitud: 17.754346517121405
# Generación 164, Mejor aptitud: 16.828331863290458
# Generación 165, Mejor aptitud: 16.828331863290458
# Generación 166, Mejor aptitud: 16.828331863290458
# Generación 167, Mejor aptitud: 16.828331863290458
# Generación 168, Mejor aptitud: 18.683750958104426
# Generación 169, Mejor aptitud: 15.745704036129354
# Generación 170, Mejor aptitud: 16.27593258840858
# Generación 171, Mejor aptitud: 17.078719276748757
# Generación 172, Mejor aptitud: 18.551859606740436
# Generación 173, Mejor aptitud: 18.551859606740436
# Generación 174, Mejor aptitud: 18.551859606740436
# Generación 175, Mejor aptitud: 19.21900030495219
# Generación 176, Mejor aptitud: 18.619229102065006
# Generación 177, Mejor aptitud: 18.619229102065006
# Generación 178, Mejor aptitud: 18.619229102065006
# Generación 179, Mejor aptitud: 18.619229102065006
# Generación 180, Mejor aptitud: 21.412218784538354
# Generación 181, Mejor aptitud: 16.6070272281044
# Generación 182, Mejor aptitud: 16.6070272281044
# Generación 183, Mejor aptitud: 16.6070272281044
# Generación 184, Mejor aptitud: 21.505956598901747
# Generación 185, Mejor aptitud: 17.701158134268027
# Generación 186, Mejor aptitud: 17.701158134268027
# Generación 187, Mejor aptitud: 18.597379746318808
# Generación 188, Mejor aptitud: 18.92271010567636
# Generación 189, Mejor aptitud: 18.92271010567636
# Generación 190, Mejor aptitud: 18.92271010567636
# Generación 191, Mejor aptitud: 21.737087836935984
# Generación 192, Mejor aptitud: 21.737087836935984
# Generación 193, Mejor aptitud: 19.32036771230395
# Generación 194, Mejor aptitud: 19.32036771230395
# Generación 195, Mejor aptitud: 18.804997279456472
# Generación 196, Mejor aptitud: 19.702630806461443
# Generación 197, Mejor aptitud: 19.13306711797283
# Generación 198, Mejor aptitud: 16.44612807858978
# Generación 199, Mejor aptitud: 16.44612807858978
# Generación 200, Mejor aptitud: 16.44612807858978
# Generación 201, Mejor aptitud: 18.285352601616864
# Generación 202, Mejor aptitud: 18.285352601616864
# Generación 203, Mejor aptitud: 20.588183115238422
# Generación 204, Mejor aptitud: 17.503556269701292
# Generación 205, Mejor aptitud: 17.46859382308324
# Generación 206, Mejor aptitud: 17.503556269701292
# Generación 207, Mejor aptitud: 18.259134895083847
# Generación 208, Mejor aptitud: 18.259134895083847
# Generación 209, Mejor aptitud: 18.259134895083847
# Generación 210, Mejor aptitud: 15.979547750990221
# Generación 211, Mejor aptitud: 15.979547750990221
# Generación 212, Mejor aptitud: 19.13298968338853
# Generación 213, Mejor aptitud: 15.879884056506995
# Generación 214, Mejor aptitud: 19.201791285766575
# Generación 215, Mejor aptitud: 19.201791285766575
# Generación 216, Mejor aptitud: 16.455869653628326
# Generación 217, Mejor aptitud: 16.455869653628326
# Generación 218, Mejor aptitud: 19.682422844762982
# Generación 219, Mejor aptitud: 18.19846028648979
# Generación 220, Mejor aptitud: 13.148745350904349
# Generación 221, Mejor aptitud: 13.148745350904349
# Generación 222, Mejor aptitud: 16.000474394419598
# Generación 223, Mejor aptitud: 16.000474394419598
# Generación 224, Mejor aptitud: 15.136304921251465
# Generación 225, Mejor aptitud: 15.541660560016965
# Generación 226, Mejor aptitud: 15.541660560016965
# Generación 227, Mejor aptitud: 13.343896913559306
# Generación 228, Mejor aptitud: 13.343896913559306
# Generación 229, Mejor aptitud: 15.756132265114985
# Generación 230, Mejor aptitud: 15.756132265114985
# Generación 231, Mejor aptitud: 17.02637348020383
# Generación 232, Mejor aptitud: 17.029892065311913
# Generación 233, Mejor aptitud: 17.029892065311913
# Generación 234, Mejor aptitud: 17.347102822049905
# Generación 235, Mejor aptitud: 15.562889283776286
# Generación 236, Mejor aptitud: 15.562889283776286
# Generación 237, Mejor aptitud: 15.562889283776286
# Generación 238, Mejor aptitud: 15.562889283776286
# Generación 239, Mejor aptitud: 15.876307184160694
# Generación 240, Mejor aptitud: 17.021104640470526
# Generación 241, Mejor aptitud: 15.341473304681884
# Generación 242, Mejor aptitud: 15.341473304681884
# Generación 243, Mejor aptitud: 16.122410365104543
# Generación 244, Mejor aptitud: 16.122410365104543
# Generación 245, Mejor aptitud: 16.30305867613201
# Generación 246, Mejor aptitud: 18.39931294528273
# Generación 247, Mejor aptitud: 18.39931294528273
# Generación 248, Mejor aptitud: 19.74661462880991
# Generación 249, Mejor aptitud: 17.00080069491159
# Generación 250, Mejor aptitud: 17.00080069491159
# Generación 251, Mejor aptitud: 15.919077425832128
# Generación 252, Mejor aptitud: 15.919077425832128
# Generación 253, Mejor aptitud: 15.919077425832128
# Generación 254, Mejor aptitud: 16.727602429482417
# Generación 255, Mejor aptitud: 15.174194227990952
# Generación 256, Mejor aptitud: 16.18464794826879
# Generación 257, Mejor aptitud: 13.480412754792326
# Generación 258, Mejor aptitud: 13.480412754792326
# Generación 259, Mejor aptitud: 15.417129419853396
# Generación 260, Mejor aptitud: 15.417129419853396
# Generación 261, Mejor aptitud: 19.303174096486018
# Generación 262, Mejor aptitud: 19.303174096486018
# Generación 263, Mejor aptitud: 18.355356981106425
# Generación 264, Mejor aptitud: 17.67444557962905
# Generación 265, Mejor aptitud: 17.27264645116584
# Generación 266, Mejor aptitud: 13.369495640209564
# Generación 267, Mejor aptitud: 13.369495640209564
# Generación 268, Mejor aptitud: 13.369495640209564
# Generación 269, Mejor aptitud: 13.369495640209564
# Generación 270, Mejor aptitud: 17.598673936411572
# Generación 271, Mejor aptitud: 15.475947201000338
# Generación 272, Mejor aptitud: 15.475947201000338
# Generación 273, Mejor aptitud: 16.08561526143447
# Generación 274, Mejor aptitud: 13.844359391505364
# Generación 275, Mejor aptitud: 13.844359391505364
# Generación 276, Mejor aptitud: 13.844359391505364
# Generación 277, Mejor aptitud: 14.761990679839101
# Generación 278, Mejor aptitud: 16.763247068240275
# Generación 279, Mejor aptitud: 17.72405798469238
# Generación 280, Mejor aptitud: 17.615959145826537
# Generación 281, Mejor aptitud: 17.615959145826537
# Generación 282, Mejor aptitud: 17.615959145826537
# Generación 283, Mejor aptitud: 17.615959145826537
# Generación 284, Mejor aptitud: 16.6383684296825
# Generación 285, Mejor aptitud: 16.6383684296825
# Generación 286, Mejor aptitud: 16.6383684296825
# Generación 287, Mejor aptitud: 18.123587976497845
# Generación 288, Mejor aptitud: 18.123587976497845
# Generación 289, Mejor aptitud: 18.186963645874613
# Generación 290, Mejor aptitud: 18.186963645874613
# Generación 291, Mejor aptitud: 18.186963645874613
# Generación 292, Mejor aptitud: 18.1502690832954
# Generación 293, Mejor aptitud: 18.1502690832954
# Generación 294, Mejor aptitud: 18.1502690832954
# Generación 295, Mejor aptitud: 18.165597499215536
# Generación 296, Mejor aptitud: 16.8181593105988
# Generación 297, Mejor aptitud: 16.8181593105988
# Generación 298, Mejor aptitud: 16.8181593105988
# Generación 299, Mejor aptitud: 15.865737113556648
# Generación 300, Mejor aptitud: 15.865737113556648
# Generación 301, Mejor aptitud: 15.865737113556648
# Generación 302, Mejor aptitud: 19.501551940044266
# Generación 303, Mejor aptitud: 15.627794734643572
# Generación 304, Mejor aptitud: 15.627794734643572
# Generación 305, Mejor aptitud: 15.627794734643572
# Generación 306, Mejor aptitud: 17.34874061592477
# Generación 307, Mejor aptitud: 17.00620709322773
# Generación 308, Mejor aptitud: 17.00620709322773
# Generación 309, Mejor aptitud: 18.09688266159222
# Generación 310, Mejor aptitud: 17.122611172195334
# Generación 311, Mejor aptitud: 17.41332133660228
# Generación 312, Mejor aptitud: 14.506578282999001
# Generación 313, Mejor aptitud: 14.506578282999001
# Generación 314, Mejor aptitud: 14.348044521383358
# Generación 315, Mejor aptitud: 14.348044521383358
# Generación 316, Mejor aptitud: 15.257454131598749
# Generación 317, Mejor aptitud: 15.257454131598749
# Generación 318, Mejor aptitud: 17.65158566992531
# Generación 319, Mejor aptitud: 18.729787856852482
# Generación 320, Mejor aptitud: 18.86118109218384
# Generación 321, Mejor aptitud: 17.879973277794477
# Generación 322, Mejor aptitud: 15.941714235409037
# Generación 323, Mejor aptitud: 15.941714235409037
# Generación 324, Mejor aptitud: 19.707726768532268
# Generación 325, Mejor aptitud: 17.31348525455421
# Generación 326, Mejor aptitud: 16.788904304358795
# Generación 327, Mejor aptitud: 16.788904304358795
# Generación 328, Mejor aptitud: 17.214198613951353
# Generación 329, Mejor aptitud: 17.214198613951353
# Generación 330, Mejor aptitud: 17.662816631699997
# Generación 331, Mejor aptitud: 18.584968943133887
# Generación 332, Mejor aptitud: 19.677585548245688
# Generación 333, Mejor aptitud: 20.208112093660233
# Generación 334, Mejor aptitud: 18.37653927429409
# Generación 335, Mejor aptitud: 18.37653927429409
# Generación 336, Mejor aptitud: 16.64924552026625
# Generación 337, Mejor aptitud: 16.64924552026625
# Generación 338, Mejor aptitud: 16.891306126415984
# Generación 339, Mejor aptitud: 16.891306126415984
# Generación 340, Mejor aptitud: 16.891306126415984
# Generación 341, Mejor aptitud: 20.863423823023567
# Generación 342, Mejor aptitud: 20.565196535562208
# Generación 343, Mejor aptitud: 20.565196535562208
# Generación 344, Mejor aptitud: 18.071687867923004
# Generación 345, Mejor aptitud: 17.620341779453838
# Generación 346, Mejor aptitud: 17.620341779453838
# Generación 347, Mejor aptitud: 18.071687867923004
# Generación 348, Mejor aptitud: 21.124986605162007
# Generación 349, Mejor aptitud: 20.761578137286563
# Generación 350, Mejor aptitud: 20.761578137286563
# Generación 351, Mejor aptitud: 20.761578137286563
# Generación 352, Mejor aptitud: 23.075089822053812
# Generación 353, Mejor aptitud: 22.84263428068735
# Generación 354, Mejor aptitud: 22.993747403138258
# Generación 355, Mejor aptitud: 17.210586708392896
# Generación 356, Mejor aptitud: 16.62638094808696
# Generación 357, Mejor aptitud: 16.62638094808696
# Generación 358, Mejor aptitud: 18.111863093739046
# Generación 359, Mejor aptitud: 19.212907748505103
# Generación 360, Mejor aptitud: 19.212907748505103
# Generación 361, Mejor aptitud: 17.128636577188757
# Generación 362, Mejor aptitud: 17.128636577188757
# Generación 363, Mejor aptitud: 20.85293037525716
# Generación 364, Mejor aptitud: 16.71663021303651
# Generación 365, Mejor aptitud: 14.555773676528673
# Generación 366, Mejor aptitud: 14.555773676528673
# Generación 367, Mejor aptitud: 14.79441243918042
# Generación 368, Mejor aptitud: 12.532862265143464
# Generación 369, Mejor aptitud: 12.532862265143464
# Generación 370, Mejor aptitud: 15.26150568682057
# Generación 371, Mejor aptitud: 15.26150568682057
# Generación 372, Mejor aptitud: 16.893559867257324
# Generación 373, Mejor aptitud: 16.250858332825516
# Generación 374, Mejor aptitud: 16.250858332825516
# Generación 375, Mejor aptitud: 16.468780683952772
# Generación 376, Mejor aptitud: 13.94783904935467
# Generación 377, Mejor aptitud: 13.94783904935467
# Generación 378, Mejor aptitud: 13.94783904935467
# Generación 379, Mejor aptitud: 13.462983030842153
# Generación 380, Mejor aptitud: 13.462983030842153
# Generación 381, Mejor aptitud: 13.307591633807618
# Generación 382, Mejor aptitud: 13.307591633807618
# Generación 383, Mejor aptitud: 13.307591633807618
# Generación 384, Mejor aptitud: 14.65955732987564
# Generación 385, Mejor aptitud: 14.65955732987564
# Generación 386, Mejor aptitud: 12.66773249075122
# Generación 387, Mejor aptitud: 12.66773249075122
# Generación 388, Mejor aptitud: 15.766228484569325
# Generación 389, Mejor aptitud: 15.766228484569325
# Generación 390, Mejor aptitud: 15.766228484569325
# Generación 391, Mejor aptitud: 15.80330910594698
# Generación 392, Mejor aptitud: 14.464197374637308
# Generación 393, Mejor aptitud: 14.464197374637308
# Generación 394, Mejor aptitud: 15.484776895682202
# Generación 395, Mejor aptitud: 15.525537621726372
# Generación 396, Mejor aptitud: 15.525537621726372
# Generación 397, Mejor aptitud: 18.09798221597771
# Generación 398, Mejor aptitud: 18.14010335524084
# Generación 399, Mejor aptitud: 13.9166502552806
# Generación 400, Mejor aptitud: 13.9166502552806
# Generación 401, Mejor aptitud: 15.268849652266027
# Generación 402, Mejor aptitud: 15.268849652266027
# Generación 403, Mejor aptitud: 14.864716173929722
# Generación 404, Mejor aptitud: 16.95135606849945
# Generación 405, Mejor aptitud: 16.95135606849945
# Generación 406, Mejor aptitud: 16.95135606849945
# Generación 407, Mejor aptitud: 14.65534257905695
# Generación 408, Mejor aptitud: 14.65534257905695
# Generación 409, Mejor aptitud: 14.65534257905695
# Generación 410, Mejor aptitud: 18.619078782591373
# Generación 411, Mejor aptitud: 18.619078782591373
# Generación 412, Mejor aptitud: 18.619078782591373
# Generación 413, Mejor aptitud: 20.61159443667617
# Generación 414, Mejor aptitud: 20.488138175002106
# Generación 415, Mejor aptitud: 17.055067397364937
# Generación 416, Mejor aptitud: 19.967651589708638
# Generación 417, Mejor aptitud: 18.90749115781324
# Generación 418, Mejor aptitud: 18.90749115781324
# Generación 419, Mejor aptitud: 12.935900475841834
# Generación 420, Mejor aptitud: 12.935900475841834
# Generación 421, Mejor aptitud: 13.726754385055827
# Generación 422, Mejor aptitud: 13.726754385055827
# Generación 423, Mejor aptitud: 13.726754385055827
# Generación 424, Mejor aptitud: 17.42198065241439
# Generación 425, Mejor aptitud: 17.42198065241439
# Generación 426, Mejor aptitud: 19.754885898760975
# Generación 427, Mejor aptitud: 19.754885898760975
# Generación 428, Mejor aptitud: 11.484177819214466
# Generación 429, Mejor aptitud: 18.606181064204705
# Generación 430, Mejor aptitud: 18.606181064204705
# Generación 431, Mejor aptitud: 15.807115730960689
# Generación 432, Mejor aptitud: 17.82383284549364
# Generación 433, Mejor aptitud: 18.811640807723307
# Generación 434, Mejor aptitud: 20.884364776732923
# Generación 435, Mejor aptitud: 21.500140500935345
# Generación 436, Mejor aptitud: 17.25120453730473
# Generación 437, Mejor aptitud: 17.25120453730473
# Generación 438, Mejor aptitud: 18.563562772869886
# Generación 439, Mejor aptitud: 15.563955766942797
# Generación 440, Mejor aptitud: 15.563955766942797
# Generación 441, Mejor aptitud: 15.563955766942797
# Generación 442, Mejor aptitud: 16.604918498736154
# Generación 443, Mejor aptitud: 16.604918498736154
# Generación 444, Mejor aptitud: 14.017895918730616
# Generación 445, Mejor aptitud: 14.017895918730616
# Generación 446, Mejor aptitud: 14.017895918730616
# Generación 447, Mejor aptitud: 19.37491604038297
# Generación 448, Mejor aptitud: 19.44399392950288
# Generación 449, Mejor aptitud: 19.44399392950288
# Generación 450, Mejor aptitud: 16.2964525666969
# Generación 451, Mejor aptitud: 15.38242553818182
# Generación 452, Mejor aptitud: 15.38242553818182
# Generación 453, Mejor aptitud: 15.38242553818182
# Generación 454, Mejor aptitud: 14.066108194063702
# Generación 455, Mejor aptitud: 14.066108194063702
# Generación 456, Mejor aptitud: 14.066108194063702
# Generación 457, Mejor aptitud: 16.878406112464077
# Generación 458, Mejor aptitud: 12.603201396364511
# Generación 459, Mejor aptitud: 16.878406112464077
# Generación 460, Mejor aptitud: 16.624640314329255
# Generación 461, Mejor aptitud: 16.624640314329255
# Generación 462, Mejor aptitud: 15.13702369975681
# Generación 463, Mejor aptitud: 13.86598379637114
# Generación 464, Mejor aptitud: 13.86598379637114
# Generación 465, Mejor aptitud: 13.86598379637114
# Generación 466, Mejor aptitud: 13.86598379637114
# Generación 467, Mejor aptitud: 14.346712176101818
# Generación 468, Mejor aptitud: 14.346712176101818
# Generación 469, Mejor aptitud: 14.346712176101818
# Generación 470, Mejor aptitud: 14.346712176101818
# Generación 471, Mejor aptitud: 12.750353604280676
# Generación 472, Mejor aptitud: 12.750353604280676
# Generación 473, Mejor aptitud: 12.750353604280676
# Generación 474, Mejor aptitud: 15.365907734666067
# Generación 475, Mejor aptitud: 15.365907734666067
# Generación 476, Mejor aptitud: 16.51232217073843
# Generación 477, Mejor aptitud: 16.51232217073843
# Generación 478, Mejor aptitud: 17.782606449996038
# Generación 479, Mejor aptitud: 18.840137948228474

# %%
# x=[]
# for i in range(30):
#     x.append(algoritmo_genetico(pobsize, num_generaciones, prob_mut, num_padres))
#     print(f"Se terminó de agregar la ejecucción [{i}]")

# %%
# plt.figure(figsize=(10, 5))  
# plt.plot(x[1],  linestyle='-', color='b')
# plt.title('Gráfico de convergencia')  
# plt.xlabel('generación')  
# plt.ylabel('mejor aptitud')  
# plt.grid(True)

# plt.show()
